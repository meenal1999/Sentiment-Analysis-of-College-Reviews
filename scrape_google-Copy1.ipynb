# %%
import import_ipynb
import requests
import pandas as pd
from bs4 import BeautifulSoup
import requests
import urllib.request, urllib.parse,urllib.error

try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
import pandas as pd
from bs4 import BeautifulSoup
import requests


from pymongo import MongoClient
import csv


import career360final as career
import mouthshutfinal as mouth
import shikhsa_work_under_progress as shiksha
import college_dunia as college
# Out:
# importing Jupyter notebook from career360final.ipynb
# importing Jupyter notebook from mouthshutfinal.ipynb
# importing Jupyter notebook from shikhsa_work_under_progress.ipynb
# shikhsa_work_under_progress.ipynb:6: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 6 of the file shikhsa_work_under_progress.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "metadata": {},
# importing Jupyter notebook from college_dunia.ipynb

# %%
list1=[]
fhandle=open('iot', encoding="utf8")
count=0
for var in fhandle:
    #print(var)
    index=var.find('zxy')
    index2=var.find('|')
    #print(index)
    list1.insert(0,var[index+4:index2-13])
leng=len(list1)
for i in range(0,leng):
    str=list1[i]

# %%
list1
# Out:
# ['University Institute Of Chemical Engineering And Technology',
#  'Noida Institute Of Engineering & Technology',
#  'Anand Institute Of Higher Technology',
#  'Government College Of Engineering, Aurangabad (Academic Autonomous)',
#  'The National Institute Of Engineering',
#  'Maharashtra Academy Of Engineering And Educational Research, Mit College Of Engineering, Pune-Pune',
#  'Adhiyamaan College Of Engineering (Engineering & Technology)',
#  'Yeshwantrao Chavan College Of Engineering-Nagpur',
#  'National Institute Of Technology, Delhi',
#  'Bengal Institute Of Technology',
#  'Sri Ramakrishna Engineering College-Coimbatore',
#  'Shri Guru Gobind Singhji Institute Of Engineering And Technology-Nanded',
#  "Vignan's Foundation For Science, Technology And Research",
#  'National Institute Of Technology, Patna',
#  'Shri Ramdeobaba College Of Engineering And Management, Ramdeo Tekdi, Gittikhadan, Katol Road, Nagpur-Nagpur',
#  'K. K. Wagh Institute Of Engineering Education & Research-Nashik',
#  'Veermata Jijabai Technological Institute',
#  'College Of Technology And Engineering-Udaipur',
#  'Centurion Institute Of Technology',
#  'Indian Institute Of Information Technology, Design & Manufacturing (IIITD&M) Kancheepuram-Chennai',
#  'Institute Of Engineering & Management-Kolkata',
#  'National Institute Of Technology, Jamshedpur',
#  'Pandit Dwarka Prasad Mishra Indian Institute Of Information Technology, Design And Manufacturing (IIITDM), Jabalpur',
#  'National Institute Of Technology, Goa',
#  'Kasegaon Education Societys Rajarambapu Institute Of Technology-Islampur',
#  'C.V.Raman College Of Engineering-Bhubaneswar',
#  'Sagi Ramakrishnam Raju Engineering College-Bhimavaram',
#  'Hindustan Institute Of Technology And Science (Hits)',
#  'Chaitanya Bharathi Institute Of Technology-Hyderabad',
#  'Siddaganga Institute Of Technology-Tumkur',
#  'National Institute Of Science & Technology-Berhampur',
#  'University Institute Of Chemical Technology, North Maharashtra University, Jalgaon',
#  'National Institute Of Technology, Srinagar',
#  'Noorul Islam Centre For Higher Education',
#  'National Institute Of Technology, Silchar',
#  'Vishwakarma Institute Of Technology-Pune',
#  'National Institute Of Technology, Raipur',
#  'Bannari Amman Institute Of Technology-Sathyamangalam',
#  'Bharati Vidyapeeth Deemed University College Of Engineering-Pune',
#  'Jaypee Institute Of Information Technology',
#  'Koneru Lakshmaiah Education Foundation',
#  'Itm University - Gwalior (School Of Engineering & Technology)-Gwalior',
#  'National Institute Of Technology, Meghalaya',
#  'Sant Longowal Institute Of Engineering & Technology-Sangrur',
#  'Cochin University Of Science And Technology-Cochin',
#  'B.S. Abdur Rahman Institute Of Science And Technology',
#  'Kumaraguru College Of Technology-Coimbatore',
#  'National Institute Of Technology, Agartala',
#  'National Institute Of Technology, Hamirpur',
#  'Amrita Viswa Vidyapeetham-Amrita Nagar (Po) ,Ettimadai',
#  'Pondicherry Engineering College',
#  'National Institute Of Technology, Kurukshetra',
#  'sona College Of Technology-Salem',
#  'Kongu Engineering College',
#  'Institute Of Technology, Nirma University',
#  'Karunya Institute Of Technology And Sciences',
#  'Indian Institute Of Science Education & Research, Mohali',
#  'Dr. B R Ambedkar National Institute Of Technology, Jalandhar',
#  'Jamia Millia Islamia (A Central University)',
#  'Manipal Institute Of Technology',
#  'Pec University Of Technology-Chandigarh',
#  'Malaviya National Institute Of Technology, Jaipur',
#  'National Institute Of Technology, Calicut',
#  'R.V. College Of Engineering-Bengaluru',
#  'Coimbatore Institute Of Technology-Coimbatore',
#  'M. S. Ramaiah Institute Of Technology-Bangalore',
#  'Kalinga Institue Of Industrial Technology',
#  'Shanmugha Arts Science Technology & Research Academy (Sastra)',
#  'Amrita School Of Engineering',
#  'National Institute Of Technology, Durgapur',
#  'Thiagarajar College Of Engineering-Madurai',
#  'National Institute Of Technology, Warangal',
#  'Thapar University-Patiala',
#  'Indian Institute Of Technology, Bhubaneswar',
#  'Indian Institute Of Technology, Jodhpur',
#  'Psg College Of Technology-Coimbatore',
#  'Motilal Nehru National Institute Of Technology',
#  'National Institute Of Technology, Karnataka-Mangalore',
#  'College Of Engineering, Pune',
#  'Indian Institute Of Technology, Mandi',
#  'Indian Institute Of Engineering Science And Technology, Shibpur',
#  'National Institute Of Technology, Rourkela-Rourkela',
#  'Visvesvaraya National Institute Of Technology, Nagpur (Deemed University)-Nagpur',
#  'Birla Institute Of Technology',
#  'Indian Institute Of Technology, Indore',
#  'Sardar Vallabhbhai National Institute Of Technology',
#  'Indian Institute Of Technology (Banaras Hindu University), Varanasi',
#  'Vellore Institute Of Technology',
#  'National Institute Of Technology, Tiruchirappalli',
#  'Indian Institute Of Technology, North Guwahati',
#  'Indian Institute Of Technology, Patna',
#  'Indian Institute Of Technology, Ropar-Rupnagar',
#  'Indian Institute Of Technology, Gandhinagar',
#  'Indian Institute Of Technology, Hyderabad',
#  'Indian Institute Of Technology, Roorkee',
#  'Indian Institute Of Technology, Kanpur',
#  'Indian Institute Of Technology, Delhi',
#  'Indian Institute Of Technology, Kharagpur',
#  'Indian Institute Of Technology, Bombay',
#  'Indian Institute Of Technology, Madras']

# %%
list1[39]
# Out:
# 'Jaypee Institute Of Information Technology'

# %%
def func(query):
    print(query)
    dfcareer=pd.DataFrame(columns=('Website','Title','Review','Placement','Infrastructure','Faculty','Social','Other','Label','Rating'))
    dfshiksha=pd.DataFrame(columns=('Website','Title','Review','Placement','Infrastructure','Faculty','Social','Other','Label','Rating'))
    dfcollege=pd.DataFrame(columns=('Website','Title','Review','Placement','Infrastructure','Faculty','Social','Other','Label','Rating'))
    dfmouthshut=pd.DataFrame(columns=('Website','Title','Review','Placement','Infrastructure','Faculty','Social','Other','Label','Rating'))
    dffinal=pd.DataFrame(columns=('Website','Title','Review','Placement','Infrastructure','Faculty','Social','Other','Label','Rating'))

    aflag=0
    sflag=0
    oflag=0
    mflag=0
    list2=[]
    #print(search(query, tld="co.in", num=100,start=0, stop=20, pause=1))
    for j in search(query, tld="co.in", num=100,start=0, stop=10, pause=1):      
        if(j.find('www.shiksha.com')>0 and sflag==0):
            print('enter shiksha')
            #print(j)
            dfshiksha=shiksha.callfunc(j)
            #print(j) 
            sflag=1
        elif(j.find('www.careers360.com')>0 and aflag==0):
            print('enter career')
            dfcareer=career.callfun(j)
            #print(j)
            aflag=1
        elif(j.find('collegedunia.com')>0 and oflag==0):
            print('enter college')
            dfcollege=college.college_dunia(j)
            #print(j) 
            oflag=1
        elif(j.find('mouthshut.com')>0 and mflag==0):
            print('enter mouthshut')
            dfmouthshut=mouth.callfunc(j)
            #print(j)
            mflag=1
            
    dffinal=dffinal.append(dfcareer)
    dffinal=dffinal.append(dfmouthshut)
    dffinal=dffinal.append(dfshiksha)
    dffinal=dffinal.append(dfcollege)
    query1="C:\\Users\\Meenal\\csvfiles\\" + query +".csv"
    #dffinal.to_csv(query1, index=False, encoding='utf-8-sig')
    
    
    
    print("over")
    return(dffinal)

# %%
length=len(list1)
for i in range(39,41):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db["aabc"] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)
# Out:
# Jaypee Institute Of Information Technology college reviews
# enter career
# enter shiksha
# enter college
# enter mouthshut
# over
# 0
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-13-cebf598299bc> in <module>
#      15         row=dffinal.loc[i]
#      16         data_dict = row.to_dict()
# ---> 17         rec_id = collection.insert_one(data_dict)
#      18
#      19
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation)
#     668             return InsertOneResult(
#     669                 self._insert(sock_info, document,
# --> 670                              bypass_doc_val=bypass_document_validation),
#     671                 self.write_concern.acknowledged)
#     672
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     573             return self._insert_one(
#     574                 sock_info, docs, ordered,
# --> 575                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     576
#     577         ids = []
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in _insert_one(self, sock_info, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     554                 command,
#     555                 codec_options=self.__write_response_codec_options,
# --> 556                 check_keys=check_keys)
#     557             _check_write_command_response([(0, result)])
#     558         else:
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     480         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     481         except BaseException as error:
# --> 482             self._raise_connection_failure(error)
#     483
#     484     def send_message(self, message, max_doc_size):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in _raise_connection_failure(self, error)
#     608             _raise_connection_failure(self.address, error)
#     609         else:
# --> 610             raise error
#     611
#     612     def __eq__(self, other):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     475                            read_concern,
#     476                            parse_write_concern_error=parse_write_concern_error,
# --> 477                            collation=collation)
#     478         except OperationFailure:
#     479             raise
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#      92
#      93     request_id, msg, size = message.query(flags, ns, 0, -1, spec,
# ---> 94                                           None, codec_options, check_keys)
#      95
#      96     if (max_bson_size is not None
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\message.py in query(options, collection_name, num_to_skip, num_to_return, query, field_selector, opts, check_keys)
#     441     data += struct.pack("<i", num_to_skip)
#     442     data += struct.pack("<i", num_to_return)
# --> 443     encoded = bson.BSON.encode(query, check_keys, opts)
#     444     data += encoded
#     445     max_bson_size = len(encoded)
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in encode(cls, document, check_keys, codec_options)
#     974             raise _CODEC_OPTIONS_TYPE_ERROR
#     975
# --> 976         return cls(_dict_to_bson(document, check_keys, codec_options))
#     977
#     978     def decode(self, codec_options=DEFAULT_CODEC_OPTIONS):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _dict_to_bson(doc, check_keys, opts, top_level)
#     756             if not top_level or key != "_id":
#     757                 elements.append(_element_to_bson(key, value,
# --> 758                                                  check_keys, opts))
#     759     except AttributeError:
#     760         raise TypeError("encoder expected a mapping type but got: %r" % (doc,))
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     741
#     742     name = _make_name(key)
# --> 743     return _name_value_to_bson(name, value, check_keys, opts)
#     744
#     745
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_list(name, value, check_keys, opts)
#     508     data = b"".join([_name_value_to_bson(next(lname), item,
#     509                                          check_keys, opts)
# --> 510                      for item in value])
#     511     return b"\x04" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     512
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     508     data = b"".join([_name_value_to_bson(next(lname), item,
#     509                                          check_keys, opts)
# --> 510                      for item in value])
#     511     return b"\x04" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     512
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_mapping(name, value, check_keys, opts)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     741
#     742     name = _make_name(key)
# --> 743     return _name_value_to_bson(name, value, check_keys, opts)
#     744
#     745
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_mapping(name, value, check_keys, opts)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     733     if not isinstance(key, string_type):
#     734         raise InvalidDocument("documents must have only string keys, "
# --> 735                               "key was %r" % (key,))
#     736     if check_keys:
#     737         if key.startswith("$"):
#
# InvalidDocument: documents must have only string keys, key was 0

# %%
length=len(list1)
for i in range(0,7):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        print(rec_id)
        print(data_dict)
        print(collection)
        rec_id = collection.insert_one(data_dict)
# Out:
# University Institute Of Chemical Engineering And Technology college reviews
# enter shiksha
# enter career
# enter college
# over
# 0
# <pymongo.results.InsertOneResult object at 0x158A18A0>
# {'Faculty': {0: ''}, 'Infrastructure': {0: ''}, 'Label': {0: ''}, 'Other': {0: 'Overall college is fine as the college is not in top 100 of india but is in top of chemical engineering of india punjab university is top university of india so degree is affilated to it helpful in future bad habit is that no development is there in colleI have taken admission through AIEEE or can say JEE mains for nowadays exam in which my rank is about 29000 i preferred choosing this college as the place is chandigarh and my university is one of the top chemical university of india my college is affilated to panjab university i.e it is within panjab university campus so you can enjoy a university life and also good company want to hire graduates from important cities.Hostels are not up to mark and is fine like other governmental and ther fees is low about rs 550 per month and mess rate is rs30 per diet and the food is not as good but fine hostel rooms are mainly sharing containing two beds, a fan, an almirah whole univerity is wifi free if you have waiting you can find pgs near university at around rs 6500 per month including food and for girls it is more better and cheaper.Seniors are good they help you towards your studies or in any other like fest, placement, etc.It is a B.tech in chemical engineering which is a four year course chemical does not means you are being taught chemical but total physics containing thermodyanamics, mass transfer, heat transfer, chemical reaction engineering, etc these topics are based on chemical but deal with calculation in physics faculty is like other government college here you can see variety of teachers like one taught very well but other you feel boring and sleepy they taught you but it depend on student how they learn and put their effort.Many companies came here like reliance, heml, samsung, nestle, itc  and many more the college get you admitted for training in different companies like iocl, bpcl, gail,  and many more as government psus does not give any stipend but private give stipend from 6k-13k depend upon that company i have been trained at iocl as it takes long time for college to confirm your training company so one has to look into themselves for where to get training.Dr. ssbuicet hold only one festival known as cyanide which is cultural fest but as college is within punjab university so many fest is held at university like jhankar, any many others fest so that student can participate.No scholarship for general student only one which is economically weaker but there are many scholarship for sc, st and obc students.'}, 'Placement': {0: 'Placement is good not as good following companies came like relaince giving about 5.5 lac and others few company also came making the average placement about 4 lacs p.a. and from strenght of about 85 student 60-65% are placed.'}, 'Rating': {0: '4.7'}, 'Review': {0: ' Overall college is fine as the college is not in top 100 of india but is in top of chemical engineering of india punjab university is top university of india so degree is affilated to it helpful in future bad habit is that no development is there in colleI have taken admission through AIEEE or can say JEE mains for nowadays exam in which my rank is about 29000 i preferred choosing this college as the place is chandigarh and my university is one of the top chemical university of india my college is affilated to panjab university i.e it is within panjab university campus so you can enjoy a university life and also good company want to hire graduates from important cities.Hostels are not up to mark and is fine like other governmental and ther fees is low about rs 550 per month and mess rate is rs30 per diet and the food is not as good but fine hostel rooms are mainly sharing containing two beds, a fan, an almirah whole univerity is wifi free if you have waiting you can find pgs near university at around rs 6500 per month including food and for girls it is more better and cheaper.Placement is good not as go ...
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'minor'), 'University Institute Of Chemical Engineering And Technology college reviews')
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-12-4ea9fa754ebe> in <module>
#      18         print(data_dict)
#      19         print(collection)
# ---> 20         rec_id = collection.insert_one(data_dict)
#      21
#      22
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation)
#     668             return InsertOneResult(
#     669                 self._insert(sock_info, document,
# --> 670                              bypass_doc_val=bypass_document_validation),
#     671                 self.write_concern.acknowledged)
#     672
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     573             return self._insert_one(
#     574                 sock_info, docs, ordered,
# --> 575                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     576
#     577         ids = []
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\collection.py in _insert_one(self, sock_info, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     554                 command,
#     555                 codec_options=self.__write_response_codec_options,
# --> 556                 check_keys=check_keys)
#     557             _check_write_command_response([(0, result)])
#     558         else:
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     480         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     481         except BaseException as error:
# --> 482             self._raise_connection_failure(error)
#     483
#     484     def send_message(self, message, max_doc_size):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in _raise_connection_failure(self, error)
#     608             _raise_connection_failure(self.address, error)
#     609         else:
# --> 610             raise error
#     611
#     612     def __eq__(self, other):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     475                            read_concern,
#     476                            parse_write_concern_error=parse_write_concern_error,
# --> 477                            collation=collation)
#     478         except OperationFailure:
#     479             raise
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#      92
#      93     request_id, msg, size = message.query(flags, ns, 0, -1, spec,
# ---> 94                                           None, codec_options, check_keys)
#      95
#      96     if (max_bson_size is not None
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\pymongo\message.py in query(options, collection_name, num_to_skip, num_to_return, query, field_selector, opts, check_keys)
#     441     data += struct.pack("<i", num_to_skip)
#     442     data += struct.pack("<i", num_to_return)
# --> 443     encoded = bson.BSON.encode(query, check_keys, opts)
#     444     data += encoded
#     445     max_bson_size = len(encoded)
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in encode(cls, document, check_keys, codec_options)
#     974             raise _CODEC_OPTIONS_TYPE_ERROR
#     975
# --> 976         return cls(_dict_to_bson(document, check_keys, codec_options))
#     977
#     978     def decode(self, codec_options=DEFAULT_CODEC_OPTIONS):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _dict_to_bson(doc, check_keys, opts, top_level)
#     756             if not top_level or key != "_id":
#     757                 elements.append(_element_to_bson(key, value,
# --> 758                                                  check_keys, opts))
#     759     except AttributeError:
#     760         raise TypeError("encoder expected a mapping type but got: %r" % (doc,))
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     741
#     742     name = _make_name(key)
# --> 743     return _name_value_to_bson(name, value, check_keys, opts)
#     744
#     745
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_list(name, value, check_keys, opts)
#     508     data = b"".join([_name_value_to_bson(next(lname), item,
#     509                                          check_keys, opts)
# --> 510                      for item in value])
#     511     return b"\x04" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     512
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     508     data = b"".join([_name_value_to_bson(next(lname), item,
#     509                                          check_keys, opts)
# --> 510                      for item in value])
#     511     return b"\x04" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     512
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_mapping(name, value, check_keys, opts)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     741
#     742     name = _make_name(key)
# --> 743     return _name_value_to_bson(name, value, check_keys, opts)
#     744
#     745
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _name_value_to_bson(name, value, check_keys, opts)
#     702     # happen once per subtype.
#     703     try:
# --> 704         return _ENCODERS[type(value)](name, value, check_keys, opts)
#     705     except KeyError:
#     706         pass
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _encode_mapping(name, value, check_keys, opts)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in <listcomp>(.0)
#     479         return b'\x03' + name + value.raw
#     480     data = b"".join([_element_to_bson(key, val, check_keys, opts)
# --> 481                      for key, val in iteritems(value)])
#     482     return b"\x03" + name + _PACK_INT(len(data) + 5) + data + b"\x00"
#     483
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\site-packages\bson\__init__.py in _element_to_bson(key, value, check_keys, opts)
#     733     if not isinstance(key, string_type):
#     734         raise InvalidDocument("documents must have only string keys, "
# --> 735                               "key was %r" % (key,))
#     736     if check_keys:
#     737         if key.startswith("$"):
#
# InvalidDocument: documents must have only string keys, key was 0

# %%
length=len(list1)
for i in range(7,14):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(14,21):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query]



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(21,28):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(28,35):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(35,42):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(42,49):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(49,56):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(56,63):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(63,70):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(70,77):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(77,84):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(84,91):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
length=len(list1)
for i in range(91,100):
    query=list1[i]+" college reviews"
    dffinal=func(query)

    # build a new client instance for MongoClient
    connection = MongoClient('localhost', 27017)
    db = connection.minor
    collection = db[query] 



    for i in range(len(dffinal)):
        print(i)
        row=dffinal.loc[i]
        data_dict = row.to_dict()
        rec_id = collection.insert_one(data_dict)

# %%
advs

# %%
        if(j.find('www.shiksha.com')>0 and sflag==0):
            print('enter shiksha')
            print(j)
            dfshiksha=shiksha.shiksha(j)
            print(j) 
            sflag=1
        elif(j.find('www.careers360.com')>0 and aflag==0):
            print('enter career')
            dfcareer=career.callfun(j)
            print(j)
            aflag=1
        elif(j.find('collegedunia.com')>0 and oflag==0):
            print('enter college')
            dfcollege=college.college_dunia(j)
            print(j) 
            oflag=1
        elif(j.find('mouthshut.com')>0 and mflag==0):
            print('enter mouthshut')
            dfmouthshut=mouth.callfunc(j)
            print(j)
            mflag=1
